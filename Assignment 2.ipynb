# %% [markdown]
# ### Huyen Trang Duong - 09/02/2026

# %%
x = 100
y = 29
sum =(x+y)
z = pow((sum*3), 2) #calculate the 2nd exponent sum*3
print("The result of calculation was: ", z)
# Out:
# The result of calculation was:  149769

# %%
a=input("Name")
b=input("Year of birth")
c=input("Age")
d=str(pow(int(c), 2))
print(b[2:]+a[:3]+d)
# Out:
# Name John
# Year of birth 1995
# Age 26
# 95Joh676

# %%
x=input("first number: ")
y=input("second number: ")
if int(x) % 2 == 0 and int(y) % 2 == 0:
    print("Both numbers are even")
elif int(x) % 2 != 0 or int(y) % 2 != 0:
    print("Both numbers are odd")
else:
    print("Both numbers are even")
# Out:
# first number:  2
# second number:  6
# Both numbers are even

# %%
# declare variables
x=int(input("Give a integer: ")) #convert number to int
sum=0
# run loop
for x in range(x):
    sum+=x
#print out result
print("The sum was: ", sum)
# Out:
# Give a integer:  4
# The sum was:  6

# %%
import random
dealer = random.randint(0, 10)
numberofguess = 0
player1=-1
# ron While loop: because not limit the player's attemps.
while player1 != dealer: 
    player = int(input("player: "))
    numberofguess+=1
    if player < dealer:
        print("try a greater number.")
    elif player > dealer:
        print("try a smaller number.")
    else:
        print("That's right! Number of tries: ",numberofguess)
        break
# Out:
# player:  3
# try a smaller number.
# player:  2
# try a smaller number.
# player:  1
# try a smaller number.
# player:  0
# That's right! Number of tries:  4

# %%
import random
dealer = random.randint(0, 10)
numberofguess1 = 0
player1 = -1
while player1 != Dealer: 
    player1 = int(input("player1: "))
    numberofguess1+=1
    if player1 < Dealer:
        print("try a greater number.")
    elif player1 > Dealer:
        print("try a smaller number.")
    else:
        print("That's right! Number of tries1: ",numberofguess1)
         #break;

numberofguess2 = 0    
player2 = -1
while player2 != Dealer:
    player2 = int(input("player2: "))
    numberofguess2+=1
    if player2 < Dealer:
        print("try a greater number.")
    elif player2 > Dealer:
        print("try a smaller number.")
    else:
        print("That's right! Number of tries2: ",numberofguess2)
        #print("player2 is winer.")
        # break

if numberofguess1 < numberofguess2:
    print("The winer is play1.")
elif numberofguess1 > numberofguess2:
    print("The winer is play2.")
else:
    print("The winer is play1 and play2")
# Out:
# player1:  6
# try a greater number.
# player1:  7
# That's right! Number of tries1:  2
# player2:  7
# That's right! Number of tries2:  1
# The winer is play2.
